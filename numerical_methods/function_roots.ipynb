# %% [markdown]
# ## Sprendžiama lygtis: $x - \sin{x} = 0.5$

# %% [markdown]
# ### 1. Pusiaukirtos metodas

# %% [markdown]
# 1. Ieškome $(a, b)$, kad $f(a)f(b) < 0$, kai $f(x) = x - \sin{x} - 0.5$ \
# Spėjimo būdu: $a = 0, b = \pi \rightarrow f(0)f(\pi) = (-0.5)(\pi - 0.5) < 0$
# 2. Taikome algoritmą

# %%
from math import sin, pi
import pandas as pd

f = lambda x: x - sin(x) - 0.5
a = 0
b = pi
error = abs(b - a)
mid_val = (a + b) / 2
f_mid_val = f(mid_val)
min_error = 1e-10
i = 0
df = pd.DataFrame(columns=['iter.i', 'a_i', 'b_i', '(a_i+b_i)/2', 'f((a_i+b_i)/2)', '|b_i-a_i|'])

# %%
def min_error_reached(error, min_error):
  if error < 2*min_error:
    print(f'Minimum error reached: {error} < {min_error}')
    return True
  return False

def reached_root(f, mid_val):
  if f(mid_val) == 0:
    print(f'Root found = {mid_val}')
    return True
  return False

# %%
while not min_error_reached(error, min_error) and not reached_root(f, mid_val):
  df.loc[i] = [i, a, b, mid_val, f_mid_val, error]
  mid_val = (a + b) / 2
  f_mid_val = f(mid_val)
  if  f(a) * f_mid_val < 0:
    b = mid_val
  else:
    a = mid_val
  error = abs(b - a)
  i += 1
# Out:
# Minimum error reached: 1.828646123414046e-10 < 1e-10

# %%
df
# Out:
#     iter.i       x_i    g(x_i)  |g(x_i)-x_i|
# 0      0.0  0.000000  0.500000  5.000000e-01
# 1      1.0  0.500000  0.979426  4.794255e-01
# 2      2.0  0.979426  1.330177  3.507517e-01
# 3      3.0  1.330177  1.471191  1.410134e-01
# 4      4.0  1.471191  1.495043  2.385282e-02
# 5      5.0  1.495043  1.497132  2.088670e-03
# 6      6.0  1.497132  1.497288  1.558964e-04
# 7      7.0  1.497288  1.497299  1.146148e-05
# 8      8.0  1.497299  1.497300  8.416898e-07
# 9      9.0  1.497300  1.497300  6.180552e-08
# 10    10.0  1.497300  1.497300  4.538368e-09
# 11    11.0  1.497300  1.497300  3.332514e-10
# 12    12.0  1.497300  1.497300  2.447065e-11
# 13    13.0  1.497300  1.497300  1.796785e-12
# 14    14.0  1.497300  1.497300  1.318945e-13
# 15    15.0  1.497300  1.497300  9.769963e-15
# 16    16.0  1.497300  1.497300  6.661338e-16
# 17    17.0  1.497300  1.497300  2.220446e-16

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_iterations(df, iter_list, f, a, b):
  x = np.linspace(a, b)
  y = f(x)
  for i in iter_list:
    iter_mid_val = df.loc[i]['(a_i+b_i)/2']
    iter_f_val = df.loc[i]['f((a_i+b_i)/2)']
    plt.plot(iter_mid_val, iter_f_val, 'ro', label='_nolegend_')
    plt.plot([iter_mid_val, iter_mid_val], [0, iter_f_val], '--', label='_nolegend_')
    plt.plot([0, iter_mid_val], [iter_f_val, iter_f_val], '--', label='_nolegend_')
  plt.plot(x, y)
  plt.plot([0, b], [0, 0], '-', label='_nolegend_')
  plt.xlim(1, 2)
  plt.ylim(-0.5, 0.5)
  plt.margins(0)
  plt.legend(['f(x)'])
  plt.title('x - sin(x) = 0.5 sprendimas pusiaukirtos metodu')
  plt.show()


plot_iterations(df, df['iter.i'], lambda x: x - np.sin(x) - 0.5, 0, pi)

# %% [markdown]
# ### 2. Paprastųjų iteracijų metodas

# %% [markdown]
# 1. Pasirenkame funkciją $g$, kad $g(x) = x$ ir $f(x) = 0$ lygtys turėtų tas pačias šaknis. \
# $f(x) = x - \sin{x} - 0.5 = 0 \rightarrow x = \sin{x} + 0.5 = g(x)$
#
# 2. Pasirenkame artinį $x_0$ iš teigiamos ir neigiamos $f(x)$ reikšmės intervale $x_0\in[0, \pi]$ aplink šaknį, \
# Pavyzdžiui $x_0 = 0$
#
# 3. Iteruojame $x_{i+1} = g(x_i)$, iki kol $|g(x_i) - x_i| \leq \frac{1-q}{q}\epsilon$, su pasirinkta paklaida $\epsilon$, kur $q = \max_{[0;\pi]}|g'(x_i)| = \max_{[0;\pi]}|\cos{x_i}| = 1$ \
# Ir kadangi $\max(|\cos{x_i}|) = 1 < 1$ netiesa, tai procesas konverguos.

# %%
from math import sin, cos, pi
import pandas as pd

g = lambda x: sin(x) + 0.5
g_ = lambda x: cos(x)
a = 0
x_i = a
b = pi
min_error = 1e-10
f_error = lambda x: abs(g(x) - x)
error = f_error(x_i)
min_error_bound = (1 - 1) / 1 * min_error # q
i = 0

def min_error_reached(error, min_error_bound):
  return error <= min_error_bound

df = pd.DataFrame(columns=['iter.i', 'x_i', 'g(x_i)', '|g(x_i)-x_i|'])

# %%
while not min_error_reached(error, min_error_bound):
  x_next = g(x_i)
  df.loc[i] = [i, x_i, x_next, error]
  x_i = x_next
  error = f_error(x_i)
  i += 1

# %%
df
# Out:
#     iter.i       x_i    g(x_i)  |g(x_i)-x_i|
# 0      0.0  0.000000  0.500000  5.000000e-01
# 1      1.0  0.500000  0.979426  4.794255e-01
# 2      2.0  0.979426  1.330177  3.507517e-01
# 3      3.0  1.330177  1.471191  1.410134e-01
# 4      4.0  1.471191  1.495043  2.385282e-02
# 5      5.0  1.495043  1.497132  2.088670e-03
# 6      6.0  1.497132  1.497288  1.558964e-04
# 7      7.0  1.497288  1.497299  1.146148e-05
# 8      8.0  1.497299  1.497300  8.416898e-07
# 9      9.0  1.497300  1.497300  6.180552e-08
# 10    10.0  1.497300  1.497300  4.538368e-09
# 11    11.0  1.497300  1.497300  3.332514e-10
# 12    12.0  1.497300  1.497300  2.447065e-11
# 13    13.0  1.497300  1.497300  1.796785e-12
# 14    14.0  1.497300  1.497300  1.318945e-13
# 15    15.0  1.497300  1.497300  9.769963e-15
# 16    16.0  1.497300  1.497300  6.661338e-16
# 17    17.0  1.497300  1.497300  2.220446e-16

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_iterations(df, iter_list, f, a, b):
  x = np.linspace(a, b)
  y = f(x)
  for i in iter_list:
    iter_x_i = df.loc[i]['x_i']
    iter_g_x_i = df.loc[i]['g(x_i)']
    plt.plot(iter_x_i, iter_g_x_i, 'ro', label='_nolegend_')
    plt.plot([iter_x_i, iter_x_i], [0, iter_g_x_i], '--', label='_nolegend_')
    plt.plot([0, iter_x_i], [iter_g_x_i, iter_g_x_i], '--', label='_nolegend_')
  plt.plot(x, y)
  y = np.sin(x) + 0.5
  plt.plot(x, y)
  y = x
  plt.plot(x, y)
  plt.plot([0, b], [0, 0], '-', label='_nolegend_')
  # plt.xlim(1, 2)
  # plt.ylim(-0.5, 0.5)
  plt.legend(['f(x)', 'g(x)', 'x'])
  plt.title('x - sin(x) = 0.5 sprendimas paprastųjų iteracijų metodu')
  plt.margins(0)
  plt.show()


plot_iterations(df, df['iter.i'], lambda x: x - np.sin(x) - 0.5, 0, pi)
